# %% [markdown]
# <a href="https://colab.research.google.com/github/jasminexue1202/Programming-with-Python/blob/main/HW2_Q1_JASMINEXUE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
upload = files.upload ()
# Out:
#      <input type="file" id="files-620ee4fa-bb4b-4c05-b73a-6e36641d828f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-620ee4fa-bb4b-4c05-b73a-6e36641d828f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv('HW2_Cereals.csv')
print(df)
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100%_Bran   N    C        70        4    1     130   10.0
# 1           100%_Natural_Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran_with_Extra_Fiber   K    C        50        4    0     140   14.0
# 4              Almond_Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat_Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties_Honey_Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
x_var = 'shelf'
y_var = 'rating'

df.plot.scatter(x = x_var, y = y_var, legend = False)
# Out:
# <Axes: xlabel='shelf', ylabel='rating'>

# %%
x_var = "shelf"
y_var = 'rating'
df4ssb = df

ax = df4ssb.boxplot(column=y_var, by=x_var)
ax.set_xlabel(x_var)
ax.set_ylabel(y_var)
ax.set_title(y_var + " by " + x_var)
# Out:
# Text(0.5, 1.0, 'rating by shelf')

# %%
number_df = df.select_dtypes(include = ['number'])
df4heatmaps = number_df

corr = df4heatmaps.corr()

sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns)
# Out:
# <Axes: >
